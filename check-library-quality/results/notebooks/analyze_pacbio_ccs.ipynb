# %% [markdown]
# # Analyze PacBio CCSs
#
# This notebook analyzes the PacBio CCSs that have been previously aligned and parsed with [alignparse](https://jbloomlab.github.io/alignparse/).

# %%
import os
import yaml
import altair as alt
import pandas as pd
import alignparse.targets

# %%
# Set to "../" if running locally and "" if running through Snakemake
path_prefix = ""

# %% [markdown]
# Get configuration information:

# %%
# If you are running notebook interactively rather than in pipeline that handles
# working directories, you may have to first `os.chdir` to appropriate directory.

with open(path_prefix + "config.yaml") as f:
    config = yaml.safe_load(f)

# %% [markdown]
# Read in the PacBio runs:

# %%
pacbio_runs = (
    pd.read_csv(path_prefix + config["runs"])
    .assign(subdir=lambda x: path_prefix + "results/process_ccs/" + x["run"])
    .rename(columns={"run": "pacbioRun"})
)

pacbio_runs
# Out:
#              library    pacbioRun  \
# 0    229E_tile_lib_1   229E_tile1
# 1    229E_tile_lib_2   229E_tile2
# 2    229E_tile_lib_3   229E_tile3
# 3    229E_tile_lib_4   229E_tile4
# 4    229E_tile_lib_5   229E_tile5
# 5    229E_tile_lib_6   229E_tile6
# 6    229E_tile_lib_7   229E_tile7
# 7    229E_tile_lib_8   229E_tile8
# 8    229E_tile_lib_9   229E_tile9
# 9   229E_tile_lib_10  229E_tile10
# 10  229E_tile_lib_13  229E_tile13
#
#                                                 fastq        design  \
# 0   /fh/fast/bloom_j/SR/ngs/pacbio/240903_SheriHar...  Plasmid_Pool
# 1   /fh/fast/bloom_j/SR/ngs/pacbio/240903_SheriHar...  Plasmid_Pool
# 2   /fh/fast/bloom_j/SR/ngs/pacbio/240903_SheriHar...  Plasmid_Pool
# 3   /fh/fast/bloom_j/SR/ngs/pacbio/240903_SheriHar...  Plasmid_Pool
# 4   /fh/fast/bloom_j/SR/ngs/pacbio/240903_SheriHar...  Plasmid_Pool
# 5   /fh/fast/bloom_j/SR/ngs/pacbio/240903_SheriHar...  Plasmid_Pool
# 6   /fh/fast/bloom_j/SR/ngs/pacbio/240903_SheriHar...  Plasmid_Pool
# 7   /fh/fast/bloom_j/SR/ngs/pacbio/240903_SheriHar...  Plasmid_Pool
# 8   /fh/fast/bloom_j/SR/ngs/pacbio/240903_SheriHar...  Plasmid_Pool
# 9   /fh/fast/bloom_j/SR/ngs/pacbio/240903_SheriHar...  Plasmid_Pool
# 10  /fh/fast/bloom_j/SR/ngs/pacbio/240903_SheriHar...  Plasmid_Pool
#
#                              subdir
# 0    results/process_ccs/229E_tile1
# 1    results/process_ccs/229E_tile2
# 2    results/process_ccs/229E_tile3
# 3    results/process_ccs/229E_tile4
# 4    results/process_ccs/229E_tile5
# 5    results/process_ccs/229E_tile6
# 6    results/process_ccs/229E_tile7
# 7    results/process_ccs/229E_tile8
# 8    results/process_ccs/229E_tile9
# 9   results/process_ccs/229E_tile10
# 10  results/process_ccs/229E_tile13

# %% [markdown]
# ## Stats on CCS alignments
# Read and plot the alignment stats from running `alignparse` on the PacBio CCSs:

# %%
readstats = pd.concat(
    [
        (
            pd.read_csv(os.path.join(row.subdir, "readstats.csv")).assign(
                pacbioRun=row.pacbioRun, library=row.library
            )
        )
        for row in pacbio_runs.itertuples()
    ],
    ignore_index=True,
)

readstats_chart = (
    alt.Chart(readstats)
    .encode(
        x="count:Q",
        y=alt.Y(
            "category:N",
            axis=alt.Axis(title=None),
        ),
        tooltip=readstats.columns.tolist(),
        facet=alt.Facet("pacbioRun:N", columns=2, title=None),
    )
    .mark_bar()
    .properties(width=250, height=50)
    .resolve_scale(x="independent", y="independent")
)

readstats_chart
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Visualize target to which reads are being aligned

# %% [markdown]
# ### Barcode PCR

# %%
targets = alignparse.targets.Targets(
    seqsfile = path_prefix + "data/Barcode_PCR_amplicon.gb",
    feature_parse_specs = path_prefix + "data/Barcode_PCR_feature_parse_specs.yaml",
)

fig = targets.plot(
    ax_width=7,
    plots_indexing="genbank",
    ax_height=2,
    hspace=1.2,
)
# Out:
# /home/sharari/miniforge3/envs/dms-vep-pipeline-3/lib/python3.11/site-packages/Bio/GenBank/Scanner.py:1217: BiopythonParserWarning: Premature end of file in sequence data
#   warnings.warn(
# /home/sharari/miniforge3/envs/dms-vep-pipeline-3/lib/python3.11/site-packages/Bio/GenBank/__init__.py:843: BiopythonParserWarning: Expected sequence length 3153, found 3112 (PacBio_amplicon).
#   warnings.warn(
# /home/sharari/miniforge3/envs/dms-vep-pipeline-3/lib/python3.11/site-packages/Bio/SeqFeature.py:230: BiopythonDeprecationWarning: Please use .location.strand rather than .strand
#   warnings.warn(

# %% [markdown]
# ### Digested Plasmid Pool

# %%
targets = alignparse.targets.Targets(
    seqsfile = path_prefix + "data/Plasmid_Pool_amplicon.gb",
    feature_parse_specs = path_prefix + "data/Plasmid_Pool_feature_parse_specs.yaml",
)

fig = targets.plot(
    ax_width=7,
    plots_indexing="genbank",
    ax_height=2,
    hspace=1.2,
)
# Out:
# /home/sharari/miniforge3/envs/dms-vep-pipeline-3/lib/python3.11/site-packages/Bio/GenBank/Scanner.py:1528: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       PacBio_amplicon        3502 bp DNA     linear   UNA 04-SEP-2024\n'
# Found locus 'PacBio_amplicon' size '3502' residue_type 'DNA'
# Some fields may be wrong.
#   warnings.warn(
# /home/sharari/miniforge3/envs/dms-vep-pipeline-3/lib/python3.11/site-packages/Bio/SeqFeature.py:230: BiopythonDeprecationWarning: Please use .location.strand rather than .strand
#   warnings.warn(

# %% [markdown]
# ### GenScript Product

# %%
targets = alignparse.targets.Targets(
    seqsfile = path_prefix + "data/Genscript_Product_amplicon.gb",
    feature_parse_specs = path_prefix + "data/Genscript_Product_feature_parse_specs.yaml",
)

fig = targets.plot(
    ax_width=7,
    plots_indexing="genbank",
    ax_height=2,
    hspace=1.2,
)
# Out:
# /home/sharari/miniforge3/envs/dms-vep-pipeline-3/lib/python3.11/site-packages/Bio/GenBank/Scanner.py:1217: BiopythonParserWarning: Premature end of file in sequence data
#   warnings.warn(
# /home/sharari/miniforge3/envs/dms-vep-pipeline-3/lib/python3.11/site-packages/Bio/GenBank/__init__.py:843: BiopythonParserWarning: Expected sequence length 3153, found 3057 (PacBio_amplicon).
#   warnings.warn(
# /home/sharari/miniforge3/envs/dms-vep-pipeline-3/lib/python3.11/site-packages/Bio/SeqFeature.py:230: BiopythonDeprecationWarning: Please use .location.strand rather than .strand
#   warnings.warn(

# %% [markdown]
# ## Why were some CCSs filtered?
# Plot the number of CCSs filtered for each reason:

# %%
# CSVs holding filtered reads
filtered_csvs = pd.concat(
    [
        (
            pd.read_csv(os.path.join(row.subdir, "filtered.csv")).assign(
                pacbioRun=row.pacbioRun, library=row.library
            )
        )
        for row in pacbio_runs.itertuples()
    ],
    ignore_index=True,
)

# details for all filtered reads
filtered = pd.concat(
    [
        pd.read_csv(path_prefix + row.csv_file).assign(
            target=row.target, pacbioRun=row.pacbioRun, library=row.library
        )
        for row in filtered_csvs.itertuples()
    ],
    ignore_index=True,
)

# count reasons for filtering, then add number of non-filtered
filtered_reasons = pd.concat(
    [
        filtered.groupby(["pacbioRun", "filter_reason"], as_index=False).aggregate(
            count=pd.NamedAgg("query_name", "count")
        ),
        readstats.query('category.str.startswith("aligned")', engine="python")
        .groupby("pacbioRun", as_index=False)
        .aggregate({"count": "sum"})
        .assign(filter_reason="aligned"),
    ]
).assign(
    total_counts=lambda x: x.groupby("pacbioRun")["count"].transform("sum"),
    frac_counts=lambda x: x["count"] / x["total_counts"],
)

# make chart
filtered_chart = (
    alt.Chart(filtered_reasons)
    .encode(
        x="count:Q",
        y=alt.Y(
            "filter_reason:N",
            axis=alt.Axis(title=None),
        ),
        color="is_aligned:N",
        tooltip=filtered_reasons.columns.tolist(),
        facet=alt.Facet("pacbioRun:N", columns=2, title=None),
    )
    .mark_bar()
    .properties(width=250, height=75)
    .resolve_scale(x="independent", y="independent")
    .transform_filter(alt.datum.frac_counts > 0.01)
    .transform_calculate(is_aligned=alt.datum.filter_reason == "aligned")
)

# Save the filtering plot
filtered_chart.save(path_prefix + "results/filtered_chart.html")
filtered_chart
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Get CCSs that align to the amplicon

# %%
# CSVs holding aligned reads
aligned_csvs = pd.concat(
    [
        (
            pd.read_csv(os.path.join(row.subdir, "aligned.csv")).assign(
                pacbioRun=row.pacbioRun, library=row.library
            )
        )
        for row in pacbio_runs.itertuples()
    ],
    ignore_index=True,
)

assert aligned_csvs["target"].nunique() == 1

aligned = pd.concat(
    [
        (
            pd.read_csv(path_prefix + row.csv_file)
            .assign(pacbioRun=row.pacbioRun, library=row.library)
            .drop(columns=["query_clip5", "query_clip3"])
            .rename(columns={"barcode_sequence": "barcode"})
        )
        for row in aligned_csvs.itertuples()
    ],
    ignore_index=True,
)
print(f"\nRead {len(aligned):.4g} alignable CCSs:")
display(
    aligned.groupby("pacbioRun").aggregate(n_CCSs=pd.NamedAgg("query_name", "count"))
)
output_csv = path_prefix + "results/CCSs_aligned_to_amplicon.csv"
print(f"Writing to {output_csv}")
aligned.to_csv(output_csv, index=False)
# Out:
# Read 3.628e+06 alignable CCSs:
#              n_CCSs
# pacbioRun
# 229E_tile1   390890
# 229E_tile10  259860
# 229E_tile13  283930
# 229E_tile2   372928
# 229E_tile3   383489
# 229E_tile4   277893
# 229E_tile5   413542
# 229E_tile6   359930
# 229E_tile7   361929
# 229E_tile8   346633
# 229E_tile9   176597
# Writing to results/CCSs_aligned_to_amplicon.csv
